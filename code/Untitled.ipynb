# %%
import pandas as pd
df7 = pd.read_excel('Data/Merger/SMS_DATA.xlsx')
df7.rename(columns = {'Report Date':'Date'}, inplace = True)
df7["Date"] = pd.to_datetime(df7["Date"], format='mixed')
df7['Date'] = df7['Date'].dt.date
df7['Date']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 2
#       1 import pandas as pd
# ----> 2 df7 = pd.read_excel('Data/Merger/SMS_DATA.xlsx')
#       3 df7.rename(columns = {'Report Date':'Date'}, inplace = True)
#       4 df7["Date"] = pd.to_datetime(df7["Date"], format='mixed')
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=479'>480</a>     raise ValueError(
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=480'>481</a>         "Engine should not be specified when passing "
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=481'>482</a>         "an ExcelFile - ExcelFile already has the engine set"
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=482'>483</a>     )
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=484'>485</a> try:
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=485'>486</a>     data = io.parse(
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=486'>487</a>         sheet_name=sheet_name,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=487'>488</a>         header=header,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=488'>489</a>         names=names,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=489'>490</a>         index_col=index_col,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=490'>491</a>         usecols=usecols,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=491'>492</a>         dtype=dtype,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=492'>493</a>         converters=converters,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=493'>494</a>         true_values=true_values,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=494'>495</a>         false_values=false_values,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=495'>496</a>         skiprows=skiprows,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=496'>497</a>         nrows=nrows,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=497'>498</a>         na_values=na_values,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=498'>499</a>         keep_default_na=keep_default_na,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=499'>500</a>         na_filter=na_filter,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=500'>501</a>         verbose=verbose,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=501'>502</a>         parse_dates=parse_dates,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=502'>503</a>         date_parser=date_parser,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=503'>504</a>         date_format=date_format,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=504'>505</a>         thousands=thousands,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=505'>506</a>         decimal=decimal,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=506'>507</a>         comment=comment,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=507'>508</a>         skipfooter=skipfooter,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=508'>509</a>         dtype_backend=dtype_backend,
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=509'>510</a>     )
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=510'>511</a> finally:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=511'>512</a>     # make sure to close opened file handles
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=512'>513</a>     if should_close:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:1551, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1517'>1518</a> def parse(
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1518'>1519</a>     self,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1519'>1520</a>     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1537'>1538</a>     **kwds,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1538'>1539</a> ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1539'>1540</a>     """
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1540'>1541</a>     Parse specified sheet(s) into a DataFrame.
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1541'>1542</a>
#    (...)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1548'>1549</a>         DataFrame from the passed in Excel file.
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1549'>1550</a>     """
# -> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1550'>1551</a>     return self._reader.parse(
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1551'>1552</a>         sheet_name=sheet_name,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1552'>1553</a>         header=header,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1553'>1554</a>         names=names,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1554'>1555</a>         index_col=index_col,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1555'>1556</a>         usecols=usecols,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1556'>1557</a>         converters=converters,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1557'>1558</a>         true_values=true_values,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1558'>1559</a>         false_values=false_values,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1559'>1560</a>         skiprows=skiprows,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1560'>1561</a>         nrows=nrows,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1561'>1562</a>         na_values=na_values,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1562'>1563</a>         parse_dates=parse_dates,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1563'>1564</a>         date_parser=date_parser,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1564'>1565</a>         date_format=date_format,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1565'>1566</a>         thousands=thousands,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1566'>1567</a>         comment=comment,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1567'>1568</a>         skipfooter=skipfooter,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1568'>1569</a>         dtype_backend=dtype_backend,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1569'>1570</a>         **kwds,
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1570'>1571</a>     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:751, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=747'>748</a>     sheet = self.get_sheet_by_index(asheetname)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=749'>750</a> file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=750'>751</a> data = self.get_sheet_data(sheet, file_rows_needed)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=751'>752</a> if hasattr(sheet, "close"):
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=752'>753</a>     # pyxlsb opens two TemporaryFiles
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=753'>754</a>     sheet.close()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:602, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=599'>600</a> data: list[list[Scalar]] = []
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=600'>601</a> last_row_with_data = -1
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=601'>602</a> for row_number, row in enumerate(sheet.rows):
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=602'>603</a>     converted_row = [self._convert_cell(cell) for cell in row]
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=603'>604</a>     while converted_row and converted_row[-1] == "":
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=604'>605</a>         # trim trailing empty elements
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_read_only.py:81, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=76'>77</a> src = self._get_source()
#      <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=77'>78</a> parser = WorkSheetParser(src, self._shared_strings,
#      <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=78'>79</a>                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=79'>80</a>                          date_formats=self.parent._date_formats)
# ---> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=80'>81</a> for idx, row in parser.parse():
#      <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=81'>82</a>     if max_row is not None and idx > max_row:
#      <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=82'>83</a>         break
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:156, in WorkSheetParser.parse(self)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=136'>137</a> properties = {
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=137'>138</a>     PRINT_TAG: ('print_options', PrintOptions),
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=138'>139</a>     MARGINS_TAG: ('page_margins', PageMargins),
#    (...)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=150'>151</a>
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=151'>152</a> }
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=153'>154</a> it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=155'>156</a> for _, element in it:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=156'>157</a>     tag_name = element.tag
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=157'>158</a>     if tag_name in dispatcher:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\xml\etree\ElementTree.py:1257, in iterparse.<locals>.iterator(source)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1254'>1255</a> yield from pullparser.read_events()
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1255'>1256</a> # load event buffer
# -> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1256'>1257</a> data = source.read(16 * 1024)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1257'>1258</a> if not data:
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1258'>1259</a>     break
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\zipfile.py:925, in ZipExtFile.read(self, n)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=922'>923</a> self._offset = 0
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=923'>924</a> while n > 0 and not self._eof:
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=924'>925</a>     data = self._read1(n)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=925'>926</a>     if n < len(data):
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=926'>927</a>         self._readbuffer = data
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\zipfile.py:993, in ZipExtFile._read1(self, n)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=990'>991</a>     data = self._decompressor.unconsumed_tail
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=991'>992</a>     if n > len(data):
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=992'>993</a>         data += self._read2(n - len(data))
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=993'>994</a> else:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=994'>995</a>     data = self._read2(n)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\zipfile.py:1025, in ZipExtFile._read2(self, n)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1021'>1022</a> n = max(n, self.MIN_READ_SIZE)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1022'>1023</a> n = min(n, self._compress_left)
# -> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1024'>1025</a> data = self._fileobj.read(n)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1025'>1026</a> self._compress_left -= len(data)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1026'>1027</a> if not data:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\zipfile.py:745, in _SharedFile.read(self, n)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=740'>741</a>     raise ValueError("Can't read from the ZIP file while there "
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=741'>742</a>             "is an open writing handle on it. "
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=742'>743</a>             "Close the writing handle before trying to read.")
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=743'>744</a> self._file.seek(self._pos)
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=744'>745</a> data = self._file.read(n)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=745'>746</a> self._pos = self._file.tell()
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=746'>747</a> return data
#
# KeyboardInterrupt:

# %%
import pandas as pd
df6 = pd.read_excel('Data/Merger/SERVICE_REPORT.xlsx')
df6.rename(columns = {'Service Date':'Date'}, inplace = True)
df6["Date"] = pd.to_datetime(df6["Date"], format='mixed')
df6['Date'] = df6['Date'].dt.date
df6['Date']
# Out:
# 0         2023-04-19
# 1         2023-04-19
# 2         2023-04-19
# 3         2023-04-19
# 4         2023-04-19
#              ...
# 260495    2022-10-31
# 260496    2022-10-31
# 260497    2022-10-31
# 260498    2022-10-31
# 260499    2022-10-31
# Name: Date, Length: 260500, dtype: object

# %%
import pandas as pd
df8 = pd.read_excel('Data/Merger/UGA_Dist_Pop.xlsx')

#Add a new column in each data frame indicating which report it comes from 
df6['Source'] = 'SERVICE_REPORT'
df7['Source'] = 'SMS_DATA'
df8['Source'] = 'UGA_Dist_Pop'

# Concatenate the DataFrames into one and then stack them vertically
combined_df = df6.merge(df7, on=['Date', 'District'], how='outer')
combined_df
# Out:
#          Unnamed: 0_x District              Facility Health Facility Type_x  \
# 0                 0.0   KAGADI  Rinamo Health Center                     SF
# 1                 1.0   KAGADI  Rinamo Health Center                     SF
# 2                 2.0   KAGADI  Rinamo Health Center                     SF
# 3                 3.0   KAGADI  Rinamo Health Center                     SF
# 4                 4.0   KAGADI  Rinamo Health Center                     SF
# ...               ...      ...                   ...                    ...
# 2487750           NaN  MITYANA                   NaN                    NaN
# 2487751           NaN  MITYANA                   NaN                    NaN
# 2487752           NaN  MITYANA                   NaN                    NaN
# 2487753           NaN  MITYANA                   NaN                    NaN
# 2487754           NaN  MITYANA                   NaN                    NaN
#
#                    CHW Name   E-code         Issued Date        Client Name  \
# 0        Rosemary Nakakembo  384-ZGT 2023-04-06 13:28:33     Asiimwe scovia
# 1        Rosemary Nakakembo  822-VXN 2023-04-06 13:38:10    Katushabe joyce
# 2        Rosemary Nakakembo  727-BEE 2023-04-06 13:38:38  Teberowooza joyce
# 3        Rosemary Nakakembo  782-FQA 2023-04-06 13:38:56    Ajalo christine
# 4        Rosemary Nakakembo  442-ACV 2023-04-06 13:39:13     Kansiime grace
# ...                     ...      ...                 ...                ...
# 2487750                 NaN      NaN                 NaT                NaN
# 2487751                 NaN      NaN                 NaT                NaN
# 2487752                 NaN      NaN                 NaT                NaN
# 2487753                 NaN      NaN                 NaT                NaN
# 2487754                 NaN      NaN                 NaT                NaN
#
#                Date Gender_x  ...                           Referrer  \
# 0        2023-04-19   FEMALE  ...                                NaN
# 1        2023-04-19   FEMALE  ...                                NaN
# 2        2023-04-19   FEMALE  ...                                NaN
# 3        2023-04-19   FEMALE  ...                                NaN
# 4        2023-04-19   FEMALE  ...                                NaN
# ...             ...      ...  ...                                ...
# 2487750  2023-05-25      NaN  ...                       Outdoor Sign
# 2487751  2023-05-25      NaN  ...                       Outdoor Sign
# 2487752  2023-05-25      NaN  ...                       Outdoor Sign
# 2487753  2023-05-25      NaN  ...              Gov't Health Provider
# 2487754  2023-05-30      NaN  ...  Satisfied Client/Friend/Relative
#
#                                           Service Quantity Client Status  \
# 0                                             NaN      NaN           NaN
# 1                                             NaN      NaN           NaN
# 2                                             NaN      NaN           NaN
# 3                                             NaN      NaN           NaN
# 4                                             NaN      NaN           NaN
# ...                                           ...      ...           ...
# 2487750                  5 Year Implant - JADELLE      1.0           NEW
# 2487751                 3 Year Implant - IMPLANON      1.0           NEW
# 2487752                    10 Year IUD Insertions      1.0           NEW
# 2487753                                   MA/MPAC      1.0           NEW
# 2487754  Subcutaneous Injectable Services 3 month      1.0           NEW
#
#                 Reported By      Health Facility Health Facility Type_y  \
# 0                       NaN                  NaN                    NaN
# 1                       NaN                  NaN                    NaN
# 2                       NaN                  NaN                    NaN
# 3                       NaN                  NaN                    NaN
# 4                       NaN                  NaN                    NaN
# ...                     ...                  ...                    ...
# 2487750  AYA Medical Centre  AYAH Medical Centre                     SF
# 2487751  AYA Medical Centre  AYAH Medical Centre                     SF
# 2487752  AYA Medical Centre  AYAH Medical Centre                     SF
# 2487753  AYA Medical Centre  AYAH Medical Centre                     SF
# 2487754  AYA Medical Centre  AYAH Medical Centre                     SF
#
#          Is Rejected Submitter Mobile Number  Source_y
# 0                NaN                     NaN       NaN
# 1                NaN                     NaN       NaN
# 2                NaN                     NaN       NaN
# 3                NaN                     NaN       NaN
# 4                NaN                     NaN       NaN
# ...              ...                     ...       ...
# 2487750           NO            2.567782e+11  SMS_DATA
# 2487751           NO            2.567782e+11  SMS_DATA
# 2487752           NO            2.567782e+11  SMS_DATA
# 2487753           NO            2.567782e+11  SMS_DATA
# 2487754           NO            2.567008e+11  SMS_DATA
#
# [2487755 rows x 29 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2487755 entries, 0 to 2487754
# Data columns (total 29 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Unnamed: 0_x                  float64
#  1   District                      object
#  2   Facility                      object
#  3   Health Facility Type_x        object
#  4   CHW Name                      object
#  5   E-code                        object
#  6   Issued Date                   datetime64[ns]
#  7   Client Name                   object
#  8   Date                          object
#  9   Gender_x                      object
#  10  Age_x                         float64
#  11  Used Family Planning before?  object
#  12  Service Name                  object
#  13  Source_x                      object
#  14  Unnamed: 0_y                  float64
#  15  Report ID                     float64
#  16  Client                        object
#  17  Age_y                         float64
#  18  Gender_y                      object
#  19  Referrer                      object
#  20  Service                       object
#  21  Quantity                      float64
#  22  Client Status                 object
#  23  Reported By                   object
#  24  Health Facility               object
#  25  Health Facility Type_y        object
#  26  Is Rejected                   object
#  27  Submitter Mobile Number       float64
#  28  Source_y                      object
# dtypes: datetime64[ns](1), float64(7), object(21)
# memory usage: 550.4+ MB

# %%
import pandas as pd
df8 = pd.read_excel('Data/Merger/UGA_Dist_Pop.xlsx')
df8.rename(columns = {'district':'District'}, inplace = True)
df8['Source'] = 'UGA_Dist_Pop'
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   146 non-null    int64
#  1   District     146 non-null    object
#  2   2015         146 non-null    int64
#  3   2016         146 non-null    int64
#  4   2017         146 non-null    int64
#  5   2018         146 non-null    int64
#  6   2019         146 non-null    int64
#  7   2020         146 non-null    int64
#  8   2021         146 non-null    int64
#  9   2022         146 non-null    int64
#  10  2023         146 non-null    int64
#  11  2024         146 non-null    int64
#  12  2025         146 non-null    int64
#  13  2026         146 non-null    int64
#  14  2027         146 non-null    int64
#  15  2028         146 non-null    int64
#  16  2029         146 non-null    int64
#  17  2030         146 non-null    int64
#  18  Unnamed: 17  0 non-null      float64
#  19  Source       146 non-null    object
# dtypes: float64(1), int64(17), object(2)
# memory usage: 22.9+ KB

# %%
import pandas as pd
# Reset the index for both dataframes
combined_df.reset_index(inplace=True)
df8.reset_index(inplace=True)

# Perform outer join using merge on the 'District' column
combined_df_1 = combined_df.merge(df8, on='District', how='outer')
combined_df_1
# Out:
#          index_x  Unnamed: 0_x District              Facility  \
# 0            0.0           0.0   KAGADI  Rinamo Health Center
# 1            1.0           1.0   KAGADI  Rinamo Health Center
# 2            2.0           2.0   KAGADI  Rinamo Health Center
# 3            3.0           3.0   KAGADI  Rinamo Health Center
# 4            4.0           4.0   KAGADI  Rinamo Health Center
# ...          ...           ...      ...                   ...
# 2487886      NaN           NaN   Terego                   NaN
# 2487887      NaN           NaN   Tororo                   NaN
# 2487888      NaN           NaN   Wakiso                   NaN
# 2487889      NaN           NaN    Yumbe                   NaN
# 2487890      NaN           NaN    Zombo                   NaN
#
#         Health Facility Type_x            CHW Name   E-code  \
# 0                           SF  Rosemary Nakakembo  384-ZGT
# 1                           SF  Rosemary Nakakembo  822-VXN
# 2                           SF  Rosemary Nakakembo  727-BEE
# 3                           SF  Rosemary Nakakembo  782-FQA
# 4                           SF  Rosemary Nakakembo  442-ACV
# ...                        ...                 ...      ...
# 2487886                    NaN                 NaN      NaN
# 2487887                    NaN                 NaN      NaN
# 2487888                    NaN                 NaN      NaN
# 2487889                    NaN                 NaN      NaN
# 2487890                    NaN                 NaN      NaN
#
#                 Issued Date        Client Name        Date  ...       2023  \
# 0       2023-04-06 13:28:33     Asiimwe scovia  2023-04-19  ...        NaN
# 1       2023-04-06 13:38:10    Katushabe joyce  2023-04-19  ...        NaN
# 2       2023-04-06 13:38:38  Teberowooza joyce  2023-04-19  ...        NaN
# 3       2023-04-06 13:38:56    Ajalo christine  2023-04-19  ...        NaN
# 4       2023-04-06 13:39:13     Kansiime grace  2023-04-19  ...        NaN
# ...                     ...                ...         ...  ...        ...
# 2487886                 NaT                NaN         NaN  ...   251500.0
# 2487887                 NaT                NaN         NaN  ...   639700.0
# 2487888                 NaT                NaN         NaN  ...  3519300.0
# 2487889                 NaT                NaN         NaN  ...   775000.0
# 2487890                 NaT                NaN         NaN  ...   306100.0
#
#               2024       2025       2026       2027       2028       2029  \
# 0              NaN        NaN        NaN        NaN        NaN        NaN
# 1              NaN        NaN        NaN        NaN        NaN        NaN
# 2              NaN        NaN        NaN        NaN        NaN        NaN
# 3              NaN        NaN        NaN        NaN        NaN        NaN
# 4              NaN        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 2487886   257000.0   263300.0   269100.0   274700.0   280300.0   285900.0
# 2487887   653400.0   667000.0   680200.0   693100.0   705700.0   717700.0
# 2487888  3741000.0  3975300.0  4219200.0  4475400.0  4743000.0  5021300.0
# 2487889   815200.0   856600.0   899400.0   943500.0   989000.0  1035600.0
# 2487890   313900.0   321500.0   329000.0   336400.0   343600.0   350700.0
#
#               2030  Unnamed: 17        Source
# 0              NaN          NaN           NaN
# 1              NaN          NaN           NaN
# 2              NaN          NaN           NaN
# 3              NaN          NaN           NaN
# 4              NaN          NaN           NaN
# ...            ...          ...           ...
# 2487886   290300.0          NaN  UGA_Dist_Pop
# 2487887   728300.0          NaN  UGA_Dist_Pop
# 2487888  5302500.0          NaN  UGA_Dist_Pop
# 2487889  1082000.0          NaN  UGA_Dist_Pop
# 2487890   357100.0          NaN  UGA_Dist_Pop
#
# [2487891 rows x 50 columns]

# %%
combined_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2487891 entries, 0 to 2487890
# Data columns (total 50 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   index_x                       float64
#  1   Unnamed: 0_x                  float64
#  2   District                      object
#  3   Facility                      object
#  4   Health Facility Type_x        object
#  5   CHW Name                      object
#  6   E-code                        object
#  7   Issued Date                   datetime64[ns]
#  8   Client Name                   object
#  9   Date                          object
#  10  Gender_x                      object
#  11  Age_x                         float64
#  12  Used Family Planning before?  object
#  13  Service Name                  object
#  14  Source_x                      object
#  15  Unnamed: 0_y                  float64
#  16  Report ID                     float64
#  17  Client                        object
#  18  Age_y                         float64
#  19  Gender_y                      object
#  20  Referrer                      object
#  21  Service                       object
#  22  Quantity                      float64
#  23  Client Status                 object
#  24  Reported By                   object
#  25  Health Facility               object
#  26  Health Facility Type_y        object
#  27  Is Rejected                   object
#  28  Submitter Mobile Number       float64
#  29  Source_y                      object
#  30  index_y                       float64
#  31  Unnamed: 0                    float64
#  32  2015                          float64
#  33  2016                          float64
#  34  2017                          float64
#  35  2018                          float64
#  36  2019                          float64
#  37  2020                          float64
#  38  2021                          float64
#  39  2022                          float64
#  40  2023                          float64
#  41  2024                          float64
#  42  2025                          float64
#  43  2026                          float64
#  44  2027                          float64
#  45  2028                          float64
#  46  2029                          float64
#  47  2030                          float64
#  48  Unnamed: 17                   float64
#  49  Source                        object
# dtypes: datetime64[ns](1), float64(27), object(22)
# memory usage: 949.1+ MB

# %%
combined_df_1.drop(['Unnamed: 0'], axis=1,inplace=True)
combined_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2487891 entries, 0 to 2487890
# Data columns (total 49 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   index_x                       float64
#  1   Unnamed: 0_x                  float64
#  2   District                      object
#  3   Facility                      object
#  4   Health Facility Type_x        object
#  5   CHW Name                      object
#  6   E-code                        object
#  7   Issued Date                   datetime64[ns]
#  8   Client Name                   object
#  9   Date                          object
#  10  Gender_x                      object
#  11  Age_x                         float64
#  12  Used Family Planning before?  object
#  13  Service Name                  object
#  14  Source_x                      object
#  15  Unnamed: 0_y                  float64
#  16  Report ID                     float64
#  17  Client                        object
#  18  Age_y                         float64
#  19  Gender_y                      object
#  20  Referrer                      object
#  21  Service                       object
#  22  Quantity                      float64
#  23  Client Status                 object
#  24  Reported By                   object
#  25  Health Facility               object
#  26  Health Facility Type_y        object
#  27  Is Rejected                   object
#  28  Submitter Mobile Number       float64
#  29  Source_y                      object
#  30  index_y                       float64
#  31  2015                          float64
#  32  2016                          float64
#  33  2017                          float64
#  34  2018                          float64
#  35  2019                          float64
#  36  2020                          float64
#  37  2021                          float64
#  38  2022                          float64
#  39  2023                          float64
#  40  2024                          float64
#  41  2025                          float64
#  42  2026                          float64
#  43  2027                          float64
#  44  2028                          float64
#  45  2029                          float64
#  46  2030                          float64
#  47  Unnamed: 17                   float64
#  48  Source                        object
# dtypes: datetime64[ns](1), float64(26), object(22)
# memory usage: 930.1+ MB

# %%
combined_df_1["Date"] = pd.to_datetime(combined_df_1["Date"], format='mixed')
combined_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2487891 entries, 0 to 2487890
# Data columns (total 49 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   index_x                       float64
#  1   Unnamed: 0_x                  float64
#  2   District                      object
#  3   Facility                      object
#  4   Health Facility Type_x        object
#  5   CHW Name                      object
#  6   E-code                        object
#  7   Issued Date                   datetime64[ns]
#  8   Client Name                   object
#  9   Date                          datetime64[ns]
#  10  Gender_x                      object
#  11  Age_x                         float64
#  12  Used Family Planning before?  object
#  13  Service Name                  object
#  14  Source_x                      object
#  15  Unnamed: 0_y                  float64
#  16  Report ID                     float64
#  17  Client                        object
#  18  Age_y                         float64
#  19  Gender_y                      object
#  20  Referrer                      object
#  21  Service                       object
#  22  Quantity                      float64
#  23  Client Status                 object
#  24  Reported By                   object
#  25  Health Facility               object
#  26  Health Facility Type_y        object
#  27  Is Rejected                   object
#  28  Submitter Mobile Number       float64
#  29  Source_y                      object
#  30  index_y                       float64
#  31  2015                          float64
#  32  2016                          float64
#  33  2017                          float64
#  34  2018                          float64
#  35  2019                          float64
#  36  2020                          float64
#  37  2021                          float64
#  38  2022                          float64
#  39  2023                          float64
#  40  2024                          float64
#  41  2025                          float64
#  42  2026                          float64
#  43  2027                          float64
#  44  2028                          float64
#  45  2029                          float64
#  46  2030                          float64
#  47  Unnamed: 17                   float64
#  48  Source                        object
# dtypes: datetime64[ns](2), float64(26), object(21)
# memory usage: 930.1+ MB

# %%
combined_df_1['District'].isnull().sum()
# Out:
# 3

# %%
combined_df_1.head()
# Out:
#    index_x  Unnamed: 0_x District              Facility  \
# 0      0.0           0.0   KAGADI  Rinamo Health Center
# 1      1.0           1.0   KAGADI  Rinamo Health Center
# 2      2.0           2.0   KAGADI  Rinamo Health Center
# 3      3.0           3.0   KAGADI  Rinamo Health Center
# 4      4.0           4.0   KAGADI  Rinamo Health Center
#
#   Health Facility Type_x            CHW Name   E-code         Issued Date  \
# 0                     SF  Rosemary Nakakembo  384-ZGT 2023-04-06 13:28:33
# 1                     SF  Rosemary Nakakembo  822-VXN 2023-04-06 13:38:10
# 2                     SF  Rosemary Nakakembo  727-BEE 2023-04-06 13:38:38
# 3                     SF  Rosemary Nakakembo  782-FQA 2023-04-06 13:38:56
# 4                     SF  Rosemary Nakakembo  442-ACV 2023-04-06 13:39:13
#
#          Client Name       Date  ... 2023  2024 2025 2026 2027  2028  2029  \
# 0     Asiimwe scovia 2023-04-19  ...  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 1    Katushabe joyce 2023-04-19  ...  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 2  Teberowooza joyce 2023-04-19  ...  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 3    Ajalo christine 2023-04-19  ...  NaN   NaN  NaN  NaN  NaN   NaN   NaN
# 4     Kansiime grace 2023-04-19  ...  NaN   NaN  NaN  NaN  NaN   NaN   NaN
#
#   2030  Unnamed: 17 Source
# 0  NaN          NaN    NaN
# 1  NaN          NaN    NaN
# 2  NaN          NaN    NaN
# 3  NaN          NaN    NaN
# 4  NaN          NaN    NaN
#
# [5 rows x 49 columns]

# %%
combined_df_1.dropna(thresh=16)
df_2021_2022 = combined_df_1[combined_df_1['Date'].dt.year.isin([2021, 2022])]
# df_2021_2022[df_2021_2022['Date'].dt.year == 2022]
df_2021_2022
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 combined_df_1.dropna(thresh=16)
#       2 df_2021_2022 = combined_df_1[combined_df_1['Date'].dt.year.isin([2021, 2022])]
#       3 # df_2021_2022[df_2021_2022['Date'].dt.year == 2022]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6411, in DataFrame.dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6407'>6408</a>     agg_obj = self.take(indices, axis=agg_axis)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6409'>6410</a> if thresh is not no_default:
# -> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6410'>6411</a>     count = agg_obj.count(axis=agg_axis)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6411'>6412</a>     mask = count >= thresh
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6412'>6413</a> elif how == "any":
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6413'>6414</a>     # faster equivalent to 'agg_obj.count(agg_axis) == self.shape[agg_axis]'
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10442, in DataFrame.count(self, axis, numeric_only)
#   <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10437'>10438</a> else:
#   <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10438'>10439</a>     if frame._is_mixed_type or frame._mgr.any_extension_types:
#   <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10439'>10440</a>         # the or any_extension_types is really only hit for single-
#   <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10440'>10441</a>         # column frames with an extension array
# > <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10441'>10442</a>         result = notna(frame).sum(axis=axis)
#   <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10442'>10443</a>     else:
#   <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10443'>10444</a>         # GH13407
#   <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=10444'>10445</a>         series_counts = notna(frame).sum(axis=axis)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\missing.py:429, in notna(obj)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=351'>352</a> def notna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=352'>353</a>     """
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=353'>354</a>     Detect non-missing values for an array-like object.
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=354'>355</a>
#    (...)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=426'>427</a>     Name: 1, dtype: bool
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=427'>428</a>     """
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=428'>429</a>     res = isna(obj)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=429'>430</a>     if isinstance(res, bool):
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=430'>431</a>         return not res
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\missing.py:183, in isna(obj)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=105'>106</a> def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=106'>107</a>     """
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=107'>108</a>     Detect missing values for an array-like object.
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=108'>109</a>
#    (...)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=180'>181</a>     Name: 1, dtype: bool
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=181'>182</a>     """
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=182'>183</a>     return _isna(obj)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\missing.py:226, in _isna(obj, inf_as_na)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=223'>224</a>     return result
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=224'>225</a> elif isinstance(obj, ABCDataFrame):
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=225'>226</a>     return obj.isna()
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=226'>227</a> elif isinstance(obj, list):
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=227'>228</a>     return _isna_array(np.asarray(obj, dtype=object), inf_as_na=inf_as_na)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6227, in DataFrame.isna(self)
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6224'>6225</a> @doc(NDFrame.isna, klass=_shared_doc_kwargs["klass"])
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6225'>6226</a> def isna(self) -> DataFrame:
# -> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6226'>6227</a>     result = self._constructor(self._mgr.isna(func=isna))
#    <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=6227'>6228</a>     return result.__finalize__(self, method="isna")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\base.py:142, in DataManager.isna(self, func)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/base.py?line=139'>140</a> @final
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/base.py?line=140'>141</a> def isna(self: T, func) -> T:
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/base.py?line=141'>142</a>     return self.apply("apply", func=func)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=349'>350</a>         applied = b.apply(f, **kwargs)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=350'>351</a>     else:
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=351'>352</a>         applied = getattr(b, f)(**kwargs)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=352'>353</a>     result_blocks = extend_blocks(applied, result_blocks)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/managers.py?line=354'>355</a> out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:329, in Block.apply(self, func, **kwargs)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=322'>323</a> @final
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=323'>324</a> def apply(self, func, **kwargs) -> list[Block]:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=324'>325</a>     """
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=325'>326</a>     apply the function to my values; return a block if we are not
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=326'>327</a>     one
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=327'>328</a>     """
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=328'>329</a>     result = func(self.values, **kwargs)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/internals/blocks.py?line=330'>331</a>     return self._split_op_result(result)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\missing.py:183, in isna(obj)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=105'>106</a> def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=106'>107</a>     """
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=107'>108</a>     Detect missing values for an array-like object.
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=108'>109</a>
#    (...)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=180'>181</a>     Name: 1, dtype: bool
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=181'>182</a>     """
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=182'>183</a>     return _isna(obj)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\missing.py:212, in _isna(obj, inf_as_na)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=209'>210</a>     return False
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=210'>211</a> elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=211'>212</a>     return _isna_array(obj, inf_as_na=inf_as_na)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=212'>213</a> elif isinstance(obj, ABCIndex):
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=213'>214</a>     # Try to use cached isna, which also short-circuits for integer dtypes
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=214'>215</a>     #  and avoids materializing RangeIndex._values
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=215'>216</a>     if not obj._can_hold_na:
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\missing.py:294, in _isna_array(values, inf_as_na)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=291'>292</a>         result = values.isna()  # type: ignore[assignment]
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=292'>293</a> elif is_string_or_object_np_dtype(values.dtype):
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=293'>294</a>     result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=294'>295</a> elif needs_i8_conversion(dtype):
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=295'>296</a>     # this is the NaT pattern
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=296'>297</a>     result = values.view("i8") == iNaT
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\missing.py:315, in _isna_string_dtype(values, inf_as_na)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=312'>313</a> else:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=313'>314</a>     if values.ndim in {1, 2}:
# --> <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=314'>315</a>         result = libmissing.isnaobj(values, inf_as_na=inf_as_na)
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=315'>316</a>     else:
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=316'>317</a>         # 0-D, reached via e.g. mask_missing
#     <a href='file:///c%3A/Users/HP/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/dtypes/missing.py?line=317'>318</a>         result = libmissing.isnaobj(values.ravel(), inf_as_na=inf_as_na)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\missing.pyx:186, in pandas._libs.missing.isnaobj()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\missing.pyx:210, in pandas._libs.missing.isnaobj()
#
# MemoryError: Unable to allocate 19.0 MiB for an array with shape (8, 2487891) and data type uint8

# %%
#combined_df_2.to_excel('Data/DATA_SET.xlsx',engine='xlsxwriter', header=True,sheet_name='DATA_SET_1')

#combined_df_2['Service'].unique()


#GroupBy Operation - Returns the no of each service in each district.
Service_count = df_2021_2022.groupby(['District','Date'])['Service'].value_counts()
Service_count

#FP_SERVICES_FOR_VOUCHER_CLIENTS_BY_DISTRICTS.plot()
# Out:
# District  Date        Service
# ABIM      2021-06-21  MA/MPAC                                        1
#                       3 Year Implant - IMPLANON                      1
#           2021-07-15  5 Year JADELLE Removal                         3
#                       3 Year IMPLANON Removal                        2
#                       Intramuscular Injectable services 3 month      1
#                                                                   ...
# ZOMBO     2022-12-30  MA/MPAC                                      441
#                       Subcutaneous Injectable Services 3 month     294
#                       MSP/PAC                                      294
#           2022-12-31  MA/MPAC                                      852
#                       3 Year Implant - IMPLANON                     71
# Name: count, Length: 27362, dtype: int64

# %%
# Convert the Service_count Series to a DataFrame
Service_count_df = Service_count.reset_index(name='service_count')

# Create a pivot table using the pivot_table function
pivot_table_df = Service_count_df.pivot_table(index='District', columns=['Date', 'Service'], values='service_count')

# If you want to reset the index to make 'District' and 'Date' as regular columns
#pivot_table_df.reset_index(inplace=True)

# Print the pivot table
Service_count_df
# Out:
#       District       Date                                    Service  \
# 0         ABIM 2021-06-21                                    MA/MPAC
# 1         ABIM 2021-06-21                  3 Year Implant - IMPLANON
# 2         ABIM 2021-07-15                     5 Year JADELLE Removal
# 3         ABIM 2021-07-15                    3 Year IMPLANON Removal
# 4         ABIM 2021-07-15  Intramuscular Injectable services 3 month
# ...        ...        ...                                        ...
# 27357    ZOMBO 2022-12-30                                    MA/MPAC
# 27358    ZOMBO 2022-12-30   Subcutaneous Injectable Services 3 month
# 27359    ZOMBO 2022-12-30                                    MSP/PAC
# 27360    ZOMBO 2022-12-31                                    MA/MPAC
# 27361    ZOMBO 2022-12-31                  3 Year Implant - IMPLANON
#
#        service_count
# 0                  1
# 1                  1
# 2                  3
# 3                  2
# 4                  1
# ...              ...
# 27357            441
# 27358            294
# 27359            294
# 27360            852
# 27361             71
#
# [27362 rows x 4 columns]

# %%
#combined_df_1['District'] = combined_df_1['District'].astype(str)
pivot_table_df.columns
# Out:
# MultiIndex([('2021-01-04', ...),
#             ('2021-01-04', ...),
#             ('2021-01-04', ...),
#             ('2021-01-05', ...),
#             ('2021-01-05', ...),
#             ('2021-01-06', ...),
#             ('2021-01-06', ...),
#             ('2021-01-07', ...),
#             ('2021-01-07', ...),
#             ('2021-01-08', ...),
#             ...
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...),
#             ('2022-12-31', ...)],
#            names=['Date', 'Service'], length=7289)

# %%
# Group by 'District' and 'Service' and apply aggregation function(s) to calculate summary statistics
summary_df = Service_count_df.groupby(['Date','District', 'Service'])['service_count'].sum().reset_index()
summary_df
# Out:
#             Date District                                   Service  \
# 0     2021-01-04    YUMBE                    10 Year IUD Insertions
# 1     2021-01-04    YUMBE                 3 Year Implant - IMPLANON
# 2     2021-01-04    YUMBE                  5 Year Implant - JADELLE
# 3     2021-01-05    YUMBE                    10 Year IUD Insertions
# 4     2021-01-05    YUMBE                 3 Year Implant - IMPLANON
# ...          ...      ...                                       ...
# 27357 2022-12-31   WAKISO                                   MSP/PAC
# 27358 2022-12-31   WAKISO                    Side Effect Management
# 27359 2022-12-31   WAKISO  Subcutaneous Injectable Services 3 month
# 27360 2022-12-31    ZOMBO                 3 Year Implant - IMPLANON
# 27361 2022-12-31    ZOMBO                                   MA/MPAC
#
#        service_count
# 0                  2
# 1                  1
# 2                  2
# 3                  7
# 4                  4
# ...              ...
# 27357           2700
# 27358            150
# 27359           1650
# 27360             71
# 27361            852
#
# [27362 rows x 4 columns]

# %%
import geopandas as gpd
shape_path = r'D:\Work\Python\Data\shape\shape\uganda_districts_2019-wgs84.shp'
#pivot_table_df.values

shape = gpd.read_file(shape_path)
shape.columns
# Out:
# Index(['F15Regions', 'Male', 'Female', 'TotalPopn', 'DName2018', 'dc2018',
#        'DName2019', 'geometry'],
#       dtype='object')

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.ticker import FuncFormatter
import pandas as pd

shape_path = r'D:\Work\Python\Data\shape\shape\uganda_districts_2019-wgs84.shp'

shape = gpd.read_file(shape_path)

shape.rename(columns={'DName2019': 'District'}, inplace=True)

# Merge the shape DataFrame with the pivot_table_df using 'DName2018' as the key
#shape = pd.merge(left=shape, right=pivot_table_df, left_on='DName2018', right_on='District', how='left')
shape = pd.merge(shape, summary_df, on='District', how='outer')

# Load the natural water bodies data into a new GeoDataFrame
water_bodies_path = r'D:\Work\Python\Data\shape\shape\lk.shp'
water_bodies = gpd.read_file(water_bodies_path)


# Create the plot
fig, ax = plt.subplots()

# Custom Formating Function for the colorbar/Legend
def format_func_1(value, tick_number):
    return "{:.0f}0".format(value / 100)

# Set the invisible axes
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# Plot the areas with data
shape_plot = shape.plot(ax=ax, cmap='plasma', legend=True)

# Use the values from the pivot_table_df directly for the colorbar
cax = cm.ScalarMappable(cmap='viridis')
cax.set_array(pivot_table_df.values.ravel())

# Title
ax.set_title('FP SERVICES FOR VOUCHER CLIENTS BY DISTRICTS', size=18, weight='bold')

# Add the colorbar to the plot
plt.colorbar(cax, ax=ax, label='Service Count', format=format_func_1)

# Get the districts covered by pivot_table_df
districts_with_data = pivot_table_df.index.tolist()

# Filter out the districts that have data, leaving the ones with no data (blank areas)
blank_shape = shape[~shape['District'].isin(districts_with_data)]

# Plot the blank areas with white color
blank_shape.plot(ax=ax, facecolor='white', edgecolor='grey')

# Plot the water bodies with a blue color after the main shape
water_bodies.plot(ax=ax, color='blue')  # Adjust alpha for transparency if needed


plt.show()

# %%
# shape.loc[shape['Date'] == '2023-05-17']
#shape.dtypes
shape['Date'].to_excel("Data\check.xlsx",engine='xlsxwriter',sheet_name='check_date',header=True)
#shape["Service"].unique

# %%
shape.geometry.type.unique()
# Out:
# array(['Polygon', 'MultiPolygon', None], dtype=object)

# %%
import geopandas as gpd
from shapely.geometry import Polygon

# Assuming 'water_bodies' is your GeoDataFrame with water bodies geometry

# Function to make a geometry valid by applying a small buffer
def make_valid(geometry):
    if not geometry.is_valid:
        return geometry.buffer(0)
    return geometry

# Check if water bodies geometries are valid and make them valid if not
water_bodies['geometry'] = water_bodies['geometry'].apply(make_valid)

# Now 'water_bodies' contains valid geometries

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import shapely.plotting
from shapely.geometry import Polygon
import matplotlib.cm as cm

# Define the selected dates
selected_dates = ['2021-06-13', '2021-12-22', '2022-01-31']

# Use the values from the pivot_table_df directly for the colorbar
cax = cm.ScalarMappable(cmap='viridis')
cax.set_array(pivot_table_df.values.ravel())

# Custom Formating Function for the colorbar/Legend
def format_func_1(value, tick_number):
    return "{:.0f}0".format(value / 100)

def plot_north_arrow( ax, xT=0, yT=0, scale=1 ):
    def t_s(t,xT,yT,s):
        x,y = t
        return (xT+(x*s),yT+(y*s))
    a = [(0, 5), (0, 1), (2, 0)]
    b = [(0, 5), (0, 1), (-2, 0)]
    t_pos = (0.25,6)
    t_pos_x,t_pos_y = t_s(t_pos,xT,yT,scale)
    polygon1 = Polygon( [t_s(t,xT,yT,scale) for t in a] )
    polygon2 = Polygon( [t_s(t,xT,yT,scale) for t in b] )
    shapely.plotting.plot_polygon(polygon1, add_points=False, ax=ax, color=None, facecolor='None', edgecolor='k', linewidth=2)
    shapely.plotting.plot_polygon(polygon2, add_points=False, ax=ax, color=None, facecolor='k', edgecolor='k', linewidth=None)
    ax.text(x=t_pos_x,y=t_pos_y,s='N', fontsize='medium',
            ha='center',
            va='center',weight='bold')

# Create the facet grid of subplots``
fig, axes = plt.subplots(1, len(selected_dates), figsize=(3 * len(selected_dates), 3), dpi=100)  # Adjust dpi for resolution

# Iterate over the selected dates and plot each category on a separate subplot
for i, date in enumerate(selected_dates):
    ax = axes[i]

    # Perform spatial difference operation to remove districts with data from the lake area
    # shape_without_districts_in_lake = gpd.overlay(shape, water_bodies, how='difference')

    

    shape.plot(ax=ax, color='white', edgecolor='black')

    # Plot the water bodies with a blue color after the main shape
    water_bodies.plot(ax=ax, color='blue')  # Adjust alpha for transparency if needed
    
    # Simplify the geometries to reduce the number of vertices (adjust tolerance as needed)
    subset_shape = shape[shape['Date'] == date].copy()  # Create a copy to avoid modifying the original GeoDataFrame
    subset_shape['geometry'] = subset_shape['geometry'].simplify(tolerance=0.01)
    
    subset_shape.plot(ax=ax, cmap='plasma', legend=True, aspect='equal')
    ax.set_title(f' {date}')
    # ax.set_axis_off()
    # ax.get_yaxis().set_visible(False)
    ax.grid(visible=True, which='major', axis='both', linestyle=":")

    plot_north_arrow( ax, xT=30, yT=3, scale=0.1)
    
    # Add the scale bar
    scalebar = AnchoredSizeBar(ax.transData, 1, "1 Meter", 3)
    ax.add_artist(scalebar)

# Title
plt.suptitle('FP SERVICES FOR VOUCHER CLIENTS BY DISTRICTS', size=15, weight='bold')

# Adjust aspect ratio for equal scaling
ax.set_aspect('equal')

# Create colorbar only once for the last subplot
plt.colorbar(cax, ax=axes.ravel().tolist(), label='Service Count', format=format_func_1)


# Show the plot
plt.show()

# %%
shape.geometry.type
# Out:
# 0        Polygon
# 1        Polygon
# 2        Polygon
# 3        Polygon
# 4        Polygon
#           ...
# 27540       None
# 27541       None
# 27542       None
# 27543       None
# 27544       None
# Length: 27545, dtype: object

# %%
# List of service names to drop
services_to_drop = ['Side Effect Management', 'Side Effect Management (Second Visit)']

# Filter the DataFrame to exclude rows with the specified service names
filtered_df = df_2021_2022[~df_2021_2022['Service'].isin(services_to_drop)]

# Now, filtered_df contain
names = {'10 Year IUD Insertions': 'IUD','10 Year IUD Removal':'IUD','5 Year Implant - JADELLE':'Implants','5 Year JADELLE Removal':'Implants','3 Year LEVOPLANT Removal':'Implants','3 Year Implant - LEVOPLANT':'Implants','3 Year IMPLANON Removal':'Implants','3 Year Implant - IMPLANON':'Implants'}
# Replace the service names in the DataFrame with the new names
filtered_df.loc[:, 'Service'] = filtered_df['Service'].replace(names)
filtered_df
# Out:
#            index_x  Unnamed: 0_x District                Facility  \
# 14575     741265.0        2542.0   KAGADI  Muhorro Medical Centre
# 14576     741266.0        2543.0   KAGADI  Muhorro Medical Centre
# 14577     741267.0        2544.0   KAGADI  Muhorro Medical Centre
# 14578     741268.0        2545.0   KAGADI  Muhorro Medical Centre
# 14579     741269.0        2546.0   KAGADI  Muhorro Medical Centre
# ...            ...           ...      ...                     ...
# 2487174  2475270.0           NaN  KAMPALA                     NaN
# 2487175  2475271.0           NaN  KAMPALA                     NaN
# 2487176  2475272.0           NaN  KAMPALA                     NaN
# 2487177  2475273.0           NaN  KAMPALA                     NaN
# 2487178  2475274.0           NaN  KAMPALA                     NaN
#
#         Health Facility Type_x          CHW Name   E-code         Issued Date  \
# 14575                       SF  Jenifer Busingye  222-ZTK 2021-01-02 17:29:39
# 14576                       SF  Jenifer Busingye  437-MCA 2021-01-02 17:32:24
# 14577                       SF  Jenifer Busingye  728-RTZ 2021-01-02 17:35:04
# 14578                       SF  Jenifer Busingye  324-ECB 2021-01-02 17:37:46
# 14579                       SF  Jenifer Busingye  228-WJU 2021-01-02 17:43:15
# ...                        ...               ...      ...                 ...
# 2487174                    NaN               NaN      NaN                 NaT
# 2487175                    NaN               NaN      NaN                 NaT
# 2487176                    NaN               NaN      NaN                 NaT
# 2487177                    NaN               NaN      NaN                 NaT
# 2487178                    NaN               NaN      NaN                 NaT
#
#                  Client Name       Date  ... 2024  2025 2026 2027 2028  2029  \
# 14575         Nakayima Lukia 2021-01-22  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 14576       Nyamigisa Sylvia 2021-01-22  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 14577    Ninzeimana Korodina 2021-01-22  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 14578         Kamusiime Gift 2021-01-22  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 14579          Kansiime Mary 2021-01-22  ...  NaN   NaN  NaN  NaN  NaN   NaN
# ...                      ...        ...  ...  ...   ...  ...  ...  ...   ...
# 2487174                  NaN 2021-12-02  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 2487175                  NaN 2021-12-02  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 2487176                  NaN 2021-12-02  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 2487177                  NaN 2021-12-02  ...  NaN   NaN  NaN  NaN  NaN   NaN
# 2487178                  NaN 2021-12-02  ...  NaN   NaN  NaN  NaN  NaN   NaN
#
#          2030 Unnamed: 17  Source       Type
# 14575     NaN         NaN     NaN  Long Term
# 14576     NaN         NaN     NaN  Long Term
# 14577     NaN         NaN     NaN  Long Term
# 14578     NaN         NaN     NaN  Long Term
# 14579     NaN         NaN     NaN  Long Term
# ...       ...         ...     ...        ...
# 2487174   NaN         NaN     NaN  Long Term
# 2487175   NaN         NaN     NaN  Long Term
# 2487176   NaN         NaN     NaN  Long Term
# 2487177   NaN         NaN     NaN  Long Term
# 2487178   NaN         NaN     NaN  Long Term
#
# [577763 rows x 50 columns]

# %%
import matplotlib.dates as mdates
# Define a function to categorize services as short term or long term
def categorize_service_type(Service):
    short_term_services = ['Condom', 'Depo', 'Oral Contraceptive Pills - POP','Oral Contraceptive Pills - COC','Female Condom','Male Condom','Emergency Contraceptive Pills','Intramuscular Injectable services 3 month','MA/MPAC','MSP/PAC','Subcutaneous Injectable Services 3 month','Female Sterilisation/Marie Stopes Ligation (MSL)','Intramuscular Injectable services 3 month - Second Visit','Intramuscular Injectable services 3 month - Third Visit','Side Effect Management']
    if Service in short_term_services:
        return 'Short Term'
    else:
        return 'Long Term'

# Apply the categorize_service_type function to the 'Service' column and store the results in a new 'Type' column
filtered_df.loc[:, 'Type'] = filtered_df['Service'].apply(categorize_service_type)

# Group by month and calculate the sum of service counts for each month
Service_count_1 = filtered_df.groupby(['District','Date','Type'])['Service'].value_counts()
Service_count_1_df = Service_count_1.reset_index(name='service_count')
# Service_count_1_df
# Group by month, 'Service', and 'Type' and calculate the sum of service counts for each combination
grouped_by_month_service_type = Service_count_1_df.groupby([pd.Grouper(key='Date', freq='M'), 'Service', 'Type'])['service_count'].sum().reset_index()
grouped_by_month_service_type = grouped_by_month_service_type.reset_index(drop=True)
grouped_by_month_service_type


# long term services
long_term_df = grouped_by_month_service_type[grouped_by_month_service_type['Type'] == 'Long Term']
long_term_df

# Group by month and calculate the total service count for 'Long Term' services
# long_term_service_count = long_term_df.groupby(pd.Grouper(key='Date', freq='M'))['service_count'].sum()
# long_term_service_count.values
# Out:
#           Date                       Service       Type  service_count
# 1   2021-01-31                           IUD  Long Term             29
# 2   2021-01-31                      Implants  Long Term             59
# 9   2021-02-28                      Implants  Long Term              5
# 13  2021-03-31                           IUD  Long Term             53
# 14  2021-03-31                      Implants  Long Term            205
# 18  2021-04-30                           IUD  Long Term              2
# 19  2021-04-30                      Implants  Long Term             56
# 23  2021-05-31                      Implants  Long Term             32
# 27  2021-06-30                           IUD  Long Term          11638
# 28  2021-06-30                      Implants  Long Term          29818
# 35  2021-06-30  Marie Stopes Vasectomy (MSV)  Long Term              1
# 41  2021-07-31                           IUD  Long Term           4357
# 42  2021-07-31                      Implants  Long Term          20634
# 54  2021-08-31                           IUD  Long Term           7389
# 55  2021-08-31                      Implants  Long Term          20896
# 67  2021-09-30                           IUD  Long Term           5162
# 68  2021-09-30                      Implants  Long Term          21325
# 79  2021-10-31                           IUD  Long Term           8599
# 80  2021-10-31                      Implants  Long Term          25821
# 92  2021-11-30                           IUD  Long Term           8749
# 93  2021-11-30                      Implants  Long Term          24351
# 105 2021-12-31                           IUD  Long Term          11012
# 106 2021-12-31                      Implants  Long Term          25062

# %%
long_term_services = long_term_df['Service'].unique()
long_term_services
# Out:
# array(['IUD', 'Implants', 'Marie Stopes Vasectomy (MSV)'], dtype=object)

# %%
y= long_term_service_count.values
x= long_term_service_count.index

# Create a larger figure with more width
plt.figure(figsize=(12, 6))

plt.plot(x,y,'b.-')
plt.xlabel('Date')
plt.ylabel('No of FP Services')
plt.title('Long Term Services')
    
# # Set the locator and formatter for the x-axis to display 7-month intervals
# locator = mdates.MonthLocator(interval=7)
# formatter = mdates.DateFormatter('%b %Y')
# plt.gca().xaxis.set_major_locator(locator)
# plt.gca().xaxis.set_major_formatter(formatter)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Filter the data for long-term services
long_term_services = long_term_df['Service'].unique()

# Create a single plot for all long-term services
plt.figure(figsize=(12, 6))

# Loop through each unique long-term service
for service in long_term_services:
    service_data = long_term_df[long_term_df['Service'] == service]
    
    # Plot the service data on the same graph
    plt.plot(service_data['Date'], service_data['service_count'], label=service)

# Customize the plot
plt.xlabel('Date')
plt.ylabel('Service Count')
plt.title('Long-Term Service Counts Over Time')
plt.legend()
plt.grid(True)

# Show the combined plot
plt.show()

# %%
from fpdf import FPDF

pdf = FPDF()
pdf.add_page()
pdf.set_font('Arial','B',16)

pdf.cell(40,10,'FP SERVICES FOR VOUCHER CLIENTS BY DISTRICTS')
pdf.ln(20)
pdf.image('FP services for voucher clients by districts.png')
pdf.output('Report_so_far','F')
# Out:
# ''
